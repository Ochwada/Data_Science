# %%
#set up code checking
import sys 
print(sys.path)
#import learntools
#print(dir(learntools))

from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex2 import*
print("setup complete")
import pandas as pd
# Out:
# ['/home/ochwada/Documents/Data Science/Kaggle/Into_ML', '/home/ochwada/anaconda3/envs/DataScience/lib/python37.zip', '/home/ochwada/anaconda3/envs/DataScience/lib/python3.7', '/home/ochwada/anaconda3/envs/DataScience/lib/python3.7/lib-dynload', '', '/home/ochwada/anaconda3/envs/DataScience/lib/python3.7/site-packages', '/home/ochwada/anaconda3/envs/DataScience/lib/python3.7/site-packages/IPython/extensions', '/home/ochwada/.ipython']
# setup complete

# %%
melb_file_path = "input/melbourne-housing-snapshot/melb_data.csv"
melb_data = pd.read_csv(melb_file_path)
melb_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
melb_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
iowa_file_path = "input/Data-for-learn-ML-Course/train.csv"
iowa_data = pd.read_csv(iowa_file_path)
#iowa_data.describe()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-817d432af6ab> in <module>
#       1 iowa_file_path = "input/Data-for-learn-ML-Course/train.csv"
# ----> 2 iowa_data = pd.read_csv(iowa_file_path)
#       3 iowa_data.describe()
#
# ...

# %%
#drop missing values (Think of na as "not available")
melb_data = melb_data.dropna(axis = 0)
